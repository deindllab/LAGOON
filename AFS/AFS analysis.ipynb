# %%
import numpy as np
import pandas 
import scipy
from scipy.signal import savgol_filter
import matplotlib.pyplot as plt
import os
import os.path 
from pathlib import Path
# %matplotlib inline

from definitions import ROOT_DIR

# %%
print(os.getcwd())
vel_before_common = []
vel_after_common = []
# Out:
# C:\Users\panf\Documents\nanobio\laser

# %%
def vel (trace, step): 
    N = len(trace)
    velocity_before = []
    velocity_after = []
    time_for_velocity = [trace["time"].iloc[i + step] for i in range (0, N-step)]
    for i in range (0, N-step):
        dlength = trace["median"].iloc[i + step] - trace["median"].iloc[i]
        dtime = trace["time"].iloc[i + step] - trace["time"].iloc[i] 
        
        if trace["time"].iloc[i+step] < start_point and trace["time"].iloc[i] >= start_point-treshold :
            velocity_before.append (dlength / dtime)

        if trace["time"].iloc[i] >= start_point and trace["time"].iloc[i+step] < start_point+treshold  :
            velocity_after.append (dlength / dtime)
     
    return(velocity_before, velocity_after)

# %%
for current_dir,dirs, files in os.walk(ROOT_DIR) :
    for el in files: 
        if el.endswith(".txt") :
            full_path = Path(current_dir) / el
            print(full_path)
            trace = pandas.read_table(full_path,  decimal=',')  
            trace.plot(x="time", y=["length"])
            plt.show()
            flag = True
            while flag:
                print(el)
                window = 300
                treshold = 30
                #window = int(input("Choose the window of median filter:")) # окно медианного фильтра 
                #treshold = int(input("Choose how many seconds we will analyze:" )) # сколько секунд до и после берем в обработку 
                start_point = int(input("Choose the start_point:" ))            
                print(trace)
                
                trace["median"]= trace["length"].rolling(window).median()
                trace["std"] = trace["length"].rolling(window).std()

              
                trace = trace[(trace.length <= trace['median']+3*trace['std']) & (trace.length >= trace['median']-3*trace['std'])]
                trace ["savgol"] = savgol_filter((trace.iloc[:, 2]),65, 3, mode='interp' )

                
                trace = trace[(trace.length <= trace['median']+3*trace['std']) & (trace.length >= trace['median']-3*trace['std'])]
                trace ["savgol"] = savgol_filter((trace.iloc[:, 2]),65, 3, mode='interp' )

                
              

                #step = int(input("Choose the step of differintiation:" )) 
                step = 125

                velocity_before, velocity_after = vel (trace, step)
                #print(velocity_before)
                #print(velocity_after)
                
                vel_before_common = vel_before_common + velocity_before
                vel_after_common = vel_after_common + velocity_after
                
                plt.plot(trace["time"], trace['savgol'] )
                plt.show()
                
                
               # time_interest =   (trace [ abs(trace["time"] < 30)  ])
                
               # plt.plot(trace["time_interest"], trace['savgol'] )
               # plt.show()
                
                plt.hist(velocity_before, density=True, bins=15, range = (-5,15))  # density=False would make counts
                plt.ylabel('Probability')
                plt.xlabel('velocity');
                
                plt.hist(velocity_after, density=True, bins=15, range = (-5,15), alpha = 0.6)  # density=False would make counts
                plt.ylabel('Probability')
                plt.xlabel('velocity'); 
                plt.show()
                
               
                exit = input("Do you want to process this trace once more(if yes print y):")
                if exit != 'y':
                    flag = False
                    vel_before_common = vel_before_common + velocity_before
                    vel_after_common = vel_after_common + velocity_after
# Out:
# C:\Users\panf\Documents\nanobio\laser\n14dc40.txt
# n14dc40.txt
# Choose the start_point:0
#           time  length
# 0     -239.994   0.000
# 1     -239.934  18.554
# 2     -239.874  28.095
# 3     -239.820  -5.893
# 4     -239.766  38.118
# ...        ...     ...
# 10484  361.758   8.969
# 10485  361.812  40.676
# 10486  361.866  61.496
# 10487  361.926  15.566
# 10488  361.980  53.589
#
# [10489 rows x 2 columns]
# <ipython-input-4-d1f472118516>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trace ["savgol"] = savgol_filter((trace.iloc[:, 2]),65, 3, mode='interp' )
# Do you want to process this trace once more(if yes print y):n
# C:\Users\panf\Documents\nanobio\laser\n17dc4.txt
# n17dc4.txt
# Choose the start_point:0
#           time   length
# 0     -240.000    0.000
# 1     -239.964  -14.234
# 2     -239.910   27.759
# 3     -239.850   51.223
# 4     -239.802  -22.085
# ...        ...      ...
# 13168  419.766 -569.085
# 13169  419.820 -550.066
# 13170  419.868 -394.658
# 13171  419.916 -427.421
# 13172  419.964 -379.418
#
# [13173 rows x 2 columns]
# <ipython-input-4-d1f472118516>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trace ["savgol"] = savgol_filter((trace.iloc[:, 2]),65, 3, mode='interp' )
# Do you want to process this trace once more(if yes print y):n
# C:\Users\panf\Documents\nanobio\laser\n1dc4.txt
# n1dc4.txt
# Choose the start_point:0
#           time   length
# 0     -239.976    0.000
# 1     -239.940  -13.393
# 2     -239.886   -9.844
# 3     -239.826   16.439
# 4     -239.778   55.778
# ...        ...      ...
# 13116  419.790  -44.366
# 13117  419.844  -10.423
# 13118  419.892  184.254
# 13119  419.940   86.788
# 13120  419.988  174.489
#
# [13121 rows x 2 columns]
# <ipython-input-4-d1f472118516>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trace ["savgol"] = savgol_filter((trace.iloc[:, 2]),65, 3, mode='interp' )
# Do you want to process this trace once more(if yes print y):n
# C:\Users\panf\Documents\nanobio\laser\n1dc76.txt
# n1dc76.txt
# Choose the start_point:0
#           time   length
# 0     -240.024    0.000
# 1     -239.970   40.030
# 2     -239.928  -39.160
# 3     -239.874  -45.120
# 4     -239.826  -71.770
# ...        ...      ...
# 10252  239.712  275.096
# 10253  239.766  314.324
# 10254  239.820  273.745
# 10255  239.874  302.179
# 10256  239.916  283.328
#
# [10257 rows x 2 columns]
# <ipython-input-4-d1f472118516>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trace ["savgol"] = savgol_filter((trace.iloc[:, 2]),65, 3, mode='interp' )
# Do you want to process this trace once more(if yes print y):n
# C:\Users\panf\Documents\nanobio\laser\n30dc10.txt
# n30dc10.txt
# Choose the start_point:8
#            time   length
# 0     -239.9928    0.000
# 1     -239.9418   -9.460
# 2     -239.8926  -50.130
# 3     -239.8416   -7.060
# 4     -239.7930  -13.640
# ...         ...      ...
# 13048  419.7822  207.703
# 13049  419.8362  215.828
# 13050  419.8842  184.167
# 13051  419.9322  198.579
# 13052  419.9802  202.010
#
# [13053 rows x 2 columns]
# <ipython-input-4-d1f472118516>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trace ["savgol"] = savgol_filter((trace.iloc[:, 2]),65, 3, mode='interp' )
# Do you want to process this trace once more(if yes print y):n
# C:\Users\panf\Documents\nanobio\laser\n54dc4.txt
# n54dc4.txt
# Choose the start_point:0
#           time   length
# 0     -240.012    0.000
# 1     -239.958   -7.071
# 2     -239.910  -43.671
# 3     -239.862  -35.184
# 4     -239.808  -67.865
# ...        ...      ...
# 12655  392.754 -237.633
# 12656  392.802 -294.827
# 12657  392.868 -325.765
# 12658  392.904 -294.190
# 12659  392.952 -247.062
#
# [12660 rows x 2 columns]
# <ipython-input-4-d1f472118516>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trace ["savgol"] = savgol_filter((trace.iloc[:, 2]),65, 3, mode='interp' )
# Do you want to process this trace once more(if yes print y):n
# C:\Users\panf\Documents\nanobio\laser\n55dc76.txt
# n55dc76.txt
# Choose the start_point:0
#           time  length
# 0     -240.024   0.000
# 1     -239.970  50.653
# 2     -239.928   4.424
# 3     -239.874 -12.108
# 4     -239.826 -22.476
# ...        ...     ...
# 10252  272.760  60.589
# 10253  272.802  75.229
# 10254  272.862  78.488
# 10255  272.898  72.525
# 10256  272.952  50.998
#
# [10257 rows x 2 columns]
# <ipython-input-4-d1f472118516>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trace ["savgol"] = savgol_filter((trace.iloc[:, 2]),65, 3, mode='interp' )
# Do you want to process this trace once more(if yes print y):n
# C:\Users\panf\Documents\nanobio\laser\n61dc76.txt
# n61dc76.txt
# Choose the start_point:0
#           time   length
# 0     -240.024    0.000
# 1     -239.970  -34.289
# 2     -239.928  -28.226
# 3     -239.874  -26.929
# 4     -239.826  -28.154
# ...        ...      ...
# 13194  419.760 -132.274
# 13195  419.802 -119.274
# 13196  419.862 -153.184
# 13197  419.898 -133.254
# 13198  419.952 -144.144
#
# [13199 rows x 2 columns]
# <ipython-input-4-d1f472118516>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trace ["savgol"] = savgol_filter((trace.iloc[:, 2]),65, 3, mode='interp' )
# Do you want to process this trace once more(if yes print y):n
# C:\Users\panf\Documents\nanobio\laser\n6dc40.txt
# n6dc40.txt
# Choose the start_point:10
#          time     length
# 0    -239.994     0.0000
# 1    -239.934    18.5400
# 2    -239.874     7.4300
# 3    -239.820   -20.0000
# 4    -239.766    -7.9700
# ...       ...        ...
# 6959  416.760   851.4920
# 6960  416.904  -272.2100
# 6961  417.498   987.7840
# 6962  417.870  1100.9668
# 6963  418.968   622.2140
#
# [6964 rows x 2 columns]
# <ipython-input-4-d1f472118516>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trace ["savgol"] = savgol_filter((trace.iloc[:, 2]),65, 3, mode='interp' )
# Do you want to process this trace once more(if yes print y):n
# C:\Users\panf\Documents\nanobio\laser\n73dc76.txt
# n73dc76.txt
# Choose the start_point:0
#           time   length
# 0     -240.024    0.000
# 1     -239.970    4.850
# 2     -239.928    0.450
# 3     -239.874   -2.880
# 4     -239.826   17.200
# ...        ...      ...
# 13194  419.760  331.307
# 13195  419.802  311.471
# 13196  419.862  299.939
# 13197  419.898  312.800
# 13198  419.952  307.855
#
# [13199 rows x 2 columns]
# <ipython-input-4-d1f472118516>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trace ["savgol"] = savgol_filter((trace.iloc[:, 2]),65, 3, mode='interp' )
# Do you want to process this trace once more(if yes print y):n
# C:\Users\panf\Documents\nanobio\laser\n74dc41.txt
# n74dc41.txt
# Choose the start_point:0
#          time   length
# 0    -240.006    0.000
# 1    -239.958   -5.694
# 2    -239.910  -37.566
# 3    -239.856  -29.890
# 4    -239.808  -38.478
# ...       ...      ...
# 7412  351.270 -869.147
# 7413  353.316 -622.367
# 7414  353.370 -760.487
# 7415  354.366 -438.357
# 7416  354.420 -466.297
#
# [7417 rows x 2 columns]
# <ipython-input-4-d1f472118516>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trace ["savgol"] = savgol_filter((trace.iloc[:, 2]),65, 3, mode='interp' )
# Do you want to process this trace once more(if yes print y):n

# %%
                #vel_before_common = [vel_before_common[i] * 0.32 for i in range(0, len (vel_before_common) )]
                #vel_after_common = [vel_after_common[i] * 0.32 for i in range(0, len (vel_after_common) )]
    

                plt.hist(vel_before_common, density=True, bins=20, range = (-5,15))  # density=False would make counts
                plt.ylabel('Probability')
                plt.xlabel('velocity(nm/s)');
             
                
                plt.hist(vel_after_common, density=True, bins=20, range = (-5,15),alpha = 0.5)  # density=False would make counts
                plt.ylabel('Probability')
                plt.xlabel('velocity(nm/s)'); 
                plt.show()
                
                vel_before_hist = np.array (vel_before_common)
                vel_after_hist = np.array (vel_after_common)

# %%
np.savetxt('before300.txt', vel_before_hist)
np.savetxt('after300.txt', vel_after_hist)
